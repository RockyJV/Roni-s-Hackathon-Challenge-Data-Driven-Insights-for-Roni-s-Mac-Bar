# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1= pd.read_csv('april_2024.csv')
df1['month']='april'

# %%
df1.head()
# Out:
#    Order #            Sent Date     Modifier     Option Group Name  \
# 0       18  2024-04-13 11:34:00      Regular                 Noods
# 1       18  2024-04-13 11:34:00      Cheddar    Choose Your Cheese
# 2       18  2024-04-13 11:34:00  Pulled Pork     Choose Your Meats
# 3       18  2024-04-13 11:34:00     Broccoli  Choose Your Toppings
# 4       18  2024-04-13 11:34:00     Tomatoes  Choose Your Toppings
#
#   Parent Menu Selection Order ID  month
# 0        Mac and Cheese    13-18  april
# 1        Mac and Cheese    13-18  april
# 2        Mac and Cheese    13-18  april
# 3        Mac and Cheese    13-18  april
# 4        Mac and Cheese    13-18  april

# %%
df2= pd.read_csv('may_2024.csv', encoding='latin-1')
df2['month']='may'
df2.head()
# Out:
#    Order #            Sent Date        Modifier  \
# 0        3  2024-05-01 11:04:00  Melted Cheddar
# 1        3  2024-05-01 11:04:00          No Mac
# 2        3  2024-05-01 11:04:00         Brisket
# 3        3  2024-05-01 11:04:00         Brisket
# 4        3  2024-05-01 11:04:00        Broccoli
#
#                           Option Group Name    Parent Menu Selection Order ID  \
# 0                 Choose Your Melted Cheese  Grilled Cheese Sandwich      1-3
# 1  Do you want Mac and Cheese added inside?  Grilled Cheese Sandwich      1-3
# 2                         Choose Your Meats  Grilled Cheese Sandwich      1-3
# 3                         Choose Your Meats  Grilled Cheese Sandwich      1-3
# 4                      Choose Your Toppings  Grilled Cheese Sandwich      1-3
#
#   month
# 0   may
# 1   may
# 2   may
# 3   may
# 4   may

# %%
df3= pd.read_csv('june_2024.csv', encoding='latin-1')
df3['month']='june'
df3.head()
# Out:
#    Order #            Sent Date  Modifier     Option Group Name  \
# 0        3  2024-06-01 11:05:00   Regular                 Noods
# 1        3  2024-06-01 11:05:00   Cheddar    Choose Your Cheese
# 2        3  2024-06-01 11:05:00   No Meat     Choose Your Meats
# 3        3  2024-06-01 11:05:00      Corn  Choose Your Toppings
# 4        3  2024-06-01 11:05:00  Parmesan  Choose Your Toppings
#
#   Parent Menu Selection Order ID month
# 0        Mac and Cheese      1-3  june
# 1        Mac and Cheese      1-3  june
# 2        Mac and Cheese      1-3  june
# 3        Mac and Cheese      1-3  june
# 4        Mac and Cheese      1-3  june

# %%
df4= pd.read_csv('july_2024.csv', encoding='latin-1')
df4['month']='july'
df4.head()
# Out:
#    Order #            Sent Date         Modifier     Option Group Name  \
# 0        3  2024-07-01 11:08:00          Regular                 Noods
# 1        3  2024-07-01 11:08:00          Alfredo    Choose Your Cheese
# 2        3  2024-07-01 11:08:00  Grilled Chicken     Choose Your Meats
# 3        3  2024-07-01 11:08:00         Broccoli  Choose Your Toppings
# 4        3  2024-07-01 11:08:00           Onions  Choose Your Toppings
#
#   Parent Menu Selection Order ID month
# 0        Mac and Cheese      1-3  july
# 1        Mac and Cheese      1-3  july
# 2        Mac and Cheese      1-3  july
# 3        Mac and Cheese      1-3  july
# 4        Mac and Cheese      1-3  july

# %%
df5= pd.read_csv('august_2024.csv', encoding='latin-1')
df5['month']='august'
df5.head()
# Out:
#    Order #            Sent Date  Modifier     Option Group Name  \
# 0        1  2024-08-01 10:41:00   Regular                 Noods
# 1        1  2024-08-01 10:41:00   Alfredo    Choose Your Cheese
# 2        1  2024-08-01 10:41:00       Ham     Choose Your Meats
# 3        1  2024-08-01 10:41:00  Parmesan  Choose Your Toppings
# 4        1  2024-08-01 10:41:00     Ranch  Choose Your Drizzles
#
#   Parent Menu Selection Order ID   month
# 0        Mac and Cheese      1-1  august
# 1        Mac and Cheese      1-1  august
# 2        Mac and Cheese      1-1  august
# 3        Mac and Cheese      1-1  august
# 4        Mac and Cheese      1-1  august

# %%
df6= pd.read_csv('september_2024.csv', encoding='latin-1')
df6['month']='september'
df6.head()
# Out:
#    Order #            Sent Date     Modifier     Option Group Name  \
# 0        1  2024-09-01 11:08:00      Regular                 Noods
# 1        1  2024-09-01 11:08:00      Cheddar    Choose Your Cheese
# 2        1  2024-09-01 11:08:00      Brisket     Choose Your Meats
# 3        1  2024-09-01 11:08:00     Broccoli  Choose Your Toppings
# 4        1  2024-09-01 11:08:00  Breadcrumbs  Choose Your Toppings
#
#   Parent Menu Selection Order ID      month
# 0        Mac and Cheese      1-1  september
# 1        Mac and Cheese      1-1  september
# 2        Mac and Cheese      1-1  september
# 3        Mac and Cheese      1-1  september
# 4        Mac and Cheese      1-1  september

# %%
df7= pd.read_csv('october_2024.csv', encoding='latin-1')
df7['month']='october'
df7.head()
# Out:
#    Order #            Sent Date  \
# 0        1  2024-10-01 10:42:00
# 1        1  2024-10-01 10:42:00
# 2        1  2024-10-01 10:42:00
# 3        1  2024-10-01 10:42:00
# 4        1  2024-10-01 10:42:00
#
#                                             Modifier       Option Group Name  \
# 0     Garden Mac (Cheddar, Broccoli, Tomatos, Ranch)  Mac and Cheese Options
# 1  Chicken Alfredo (Alfredo, Chicken, Broccoli, P...  Mac and Cheese Options
# 2   Texas BBQ (Pepper Jack, Brisket, Jalapenos, BBQ)  Mac and Cheese Options
# 3  Chicken Bacon Ranch (Cheddar, Chicken, Bacon, ...  Mac and Cheese Options
# 4  Buffalo Chicken (Cheddar, Chicken, Onions, Buf...  Mac and Cheese Options
#
#                                Parent Menu Selection Order ID    month
# 0  Mac and Cheese Party Tray (Plus FREE Garlic Br...      1-1  october
# 1  Mac and Cheese Party Tray (Plus FREE Garlic Br...      1-1  october
# 2  Mac and Cheese Party Tray (Plus FREE Garlic Br...      1-1  october
# ...

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7], ignore_index=True)

# %%
df.shape
# Out:
# (274010, 7)

# %%
df.head()
# Out:
#    Order #            Sent Date     Modifier     Option Group Name  \
# 0       18  2024-04-13 11:34:00      Regular                 Noods
# 1       18  2024-04-13 11:34:00      Cheddar    Choose Your Cheese
# 2       18  2024-04-13 11:34:00  Pulled Pork     Choose Your Meats
# 3       18  2024-04-13 11:34:00     Broccoli  Choose Your Toppings
# 4       18  2024-04-13 11:34:00     Tomatoes  Choose Your Toppings
#
#   Parent Menu Selection Order ID  month
# 0        Mac and Cheese    13-18  april
# 1        Mac and Cheese    13-18  april
# 2        Mac and Cheese    13-18  april
# 3        Mac and Cheese    13-18  april
# 4        Mac and Cheese    13-18  april

# %%
df.describe()
# Out:
#              Order #
# count  274010.000000
# mean      110.077245
# std       182.011290
# min         0.000000
# 25%        35.000000
# 50%        72.000000
# 75%       138.000000
# max      7002.000000

# %%
df.describe(include=['object', 'category'])
# Out:
#                   Sent Date Modifier     Option Group Name  \
# count                274007   274006                273838
# unique                19050      237                    14
# top     2024-10-14 17:50:00  Regular  Choose Your Toppings
# freq                     87    25787                 78431
#
#        Parent Menu Selection Order ID   month
# count                 274007   274010  274010
# unique                     7     9074       7
# top           Mac and Cheese    27-12   april
# freq                  245397      160   50000

# %%
unique_values = df['Parent Menu Selection'].unique()

# %%
unique_values
# Out:
# array(['Mac and Cheese', 'Grilled Cheese Sandwich', 'Sides/Desserts',
#        'Drinks', 'MIX',
#        'Mac and Cheese Party Tray (Plus FREE Garlic Bread)',
#        'Garlic Bread (Party Size)', nan], dtype=object)

# %%
unique_values = df['Option Group Name'].unique()
unique_values
# Out:
# array(['Noods', 'Choose Your Cheese', 'Choose Your Meats',
#        'Choose Your Toppings', 'Choose Your Drizzles', 'Choose Your Side',
#        'Choose Your Drink', nan, 'Choose Your Melted Cheese',
#        'Do you want Mac and Cheese added inside?', 'Utensils?',
#        'Mix Bases', 'Choose Your Shirt', 'Mac and Cheese Options',
#        'Sides'], dtype=object)

# %%
unique_values = df['Modifier'].unique()
unique_values
# Out:
# array(['Regular', 'Cheddar', 'Pulled Pork', 'Broccoli', 'Tomatoes',
#        'Breadcrumbs', 'BBQ', 'No Side', 'Water', 'Pepper Jack', 'Brisket',
#        'Corn', 'Mushrooms', 'Parmesan', 'No Drink', 'Alfredo',
#        'Jalapenos', 'Unlimited Fountain Drinks', 'No Toppings',
#        'Cheesy Broccoli', 'Cheesy Garlic Bread', 'No Meat', 'No Drizzle',
#        'Pepperjack', 'Bacon', 'Garlic Parmesan', 'Grilled Chicken',
#        'Bell Peppers', 'Hot Honey', 'Garlic Bread', 'Ranch', 'Cheesecake',
#        'Buffalo', 'Ham', 'Melted Cheddar', 'No Mac', 'Pesto', 'Sprite',
#        'Coke', 'Pepper Jack Mac', 'Pineapple', 'Melted Pepper Jack',
#        'MIX', 'Mix PJ And Cheddar', 'GLUTEN FREE', 'Melted Parmesan',
#        'Cheddar Mac', 'Alfredo Mac', 'Side Mac', 'Diet Coke', 'Onions',
#        'Onion', 'All Cheese!!!', 'I DO NOT NEED UTENSILS (Save waste!)',
#        'O J And BP On Side', 'Bacon On Side', 'Hot Honey On Half',
#        'MIXED Melted Cheese', 'Bbq On Side',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274010 entries, 0 to 274009
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Order #                274010 non-null  int64
#  1   Sent Date              274007 non-null  object
#  2   Modifier               274006 non-null  object
#  3   Option Group Name      273838 non-null  object
#  4   Parent Menu Selection  274007 non-null  object
#  5   Order ID               274010 non-null  object
#  6   month                  274010 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 14.6+ MB

# %%
df.to_csv('Ronis_Combined.csv')
